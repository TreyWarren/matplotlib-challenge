# %% [markdown]
# ## Observations and Insights
# * Clearly Capomulin and Ramicane were the only two drugs that consistantly decreased the size of the mice's tumors, the other drugs didn't perform much better or worse than the placebo.
# * Although there were nearly equal number of mice genders in the study, we didn't seporate any of the results by sex so seeing if either of the sucessful drugs performed better for one gender would be an interesting follow up (if this were a real study).
# * The average tumor volume was certinly perportional to the weight of each mouse.

# %% [markdown]
# ## Dependencies and starter code

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata, study_results, on='Mouse ID', how='outer')
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %% [markdown]
# ## Summary statistics

# %%
# Generate a summary statistics table of mean, median, variance, 
#  standard deviation, and SEM of the tumor volume for each regimen.

# So first we will groupby Regimen
combined_groupedby_DR = combined_df.groupby('Drug Regimen')

# Then calculate our desired summary statistics
mean_df = pd.DataFrame(combined_groupedby_DR['Tumor Volume (mm3)'].mean())
median_df = pd.DataFrame(combined_groupedby_DR['Tumor Volume (mm3)'].median())
variance_df = pd.DataFrame(combined_groupedby_DR['Tumor Volume (mm3)'].var())
stdev_df = pd.DataFrame(combined_groupedby_DR['Tumor Volume (mm3)'].std())
sem_df = pd.DataFrame(combined_groupedby_DR['Tumor Volume (mm3)'].sem())

# Then merge them into one big datafframe
Summary_statistics_df = pd.merge(mean_df, median_df, on='Drug Regimen', suffixes=('_mean','_median'))
Summary_statistics_df = pd.merge(Summary_statistics_df, variance_df, on='Drug Regimen')
Summary_statistics_df = pd.merge(Summary_statistics_df, stdev_df, on='Drug Regimen', suffixes=('_variance','_stdev'))
Summary_statistics_df = pd.merge(Summary_statistics_df, sem_df, on='Drug Regimen')

# Rename the headers just because they were a little long before
Summary_statistics_df = Summary_statistics_df.rename(columns={
    'Tumor Volume (mm3)_mean': 'Mean', 
    'Tumor Volume (mm3)_median': 'Median',
    'Tumor Volume (mm3)_variance': 'Variance',
    'Tumor Volume (mm3)_stdev': 'St.Dev',
    'Tumor Volume (mm3)': 'SEM'})

# And finally display our df with a little formatting
Summary_statistics_df.apply(lambda x: round(x,2))
# Out:
#                Mean  Median  Variance  St.Dev   SEM
# Drug Regimen
# Capomulin     40.68   41.56     24.95    4.99  0.33
# Ceftamin      52.59   51.78     39.29    6.27  0.47
# Infubinol     52.88   51.82     43.13    6.57  0.49
# Ketapril      55.24   53.70     68.55    8.28  0.60
# Naftisol      54.33   52.51     66.17    8.13  0.60
# Placebo       54.03   52.29     61.17    7.82  0.58
# Propriva      52.32   50.85     42.35    6.51  0.51
# Ramicane      40.22   40.67     23.49    4.85  0.32
# Stelasyn      54.23   52.43     59.45    7.71  0.57
# Zoniferol     53.24   51.82     48.53    6.97  0.52

# %% [markdown]
# ## Bar plots

# %%
# Using Pandas, generate a bar plot showing number of data points 
#  for each treatment regimen

pandas_bar = combined_groupedby_DR.Timepoint.count().plot(
    kind='bar', color='darkorange', width=0.75)
pandas_bar.set_ylabel('Number of Data Points')
pandas_bar.set_title('Number of Data Points Obtained for Each Regimen')
plt.show()

# %%
# Use PyPlot to do the same

x_axis = Summary_statistics_df['Mean'].keys() # 'Mean' could be any column
counts = combined_groupedby_DR.Timepoint.count() # 'Timepoint' could be any column

plt.bar(x_axis, counts, color='darkorange')
plt.xticks(rotation=90)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Data Points')
plt.title('Number of Data Points Obtained for Each Regimen')
plt.show()

# %% [markdown]
# ## Pie plots

# %%
# Using Pandas, generate a pie plot showing the distribution of 
#  female versus male mice

combined_groupedby_ID = combined_df.groupby('Mouse ID')
combined_groupedby_ID_df = pd.DataFrame(combined_groupedby_ID.max())

gender_counts = combined_groupedby_ID_df.Sex.value_counts()
gender_counts_df = pd.DataFrame(gender_counts)

gender_counts_df.plot(kind='pie', figsize=(5,5), subplots=True, 
                      explode=(0.1,0),shadow=True, autopct="%1.1f%%", 
                      legend=False)

plt.show()

# %%
# Use PyPlot to do the same

plt.pie(gender_counts, explode=(0.1,0), 
        labels=['Male', 'Female'], autopct="%1.1f%%", 
        shadow=True, startangle=90)

plt.title('Sex of Mice in Study')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
# Calculate the final tumor volume of each mouse 
#  across four of the most promising treatment regimens. 

# We will start by making a dataframe with only the final Timepoint for each mouse
# Since the Timepoints are already in ascending order per mouse, this can be 
#  acomplished by dropping the duplicate Mouse ID's and only keeping the final row
final_Timepoint_df = combined_df.drop_duplicates(subset="Mouse ID", keep='last')

# Initialize a dictionary to save our 4 drug dataframes in
final_Timepoint_df_dict = {}

# Now we begin our loop for each of the four specified drugs
for drug in ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']:

    # Filter out one drug using .loc[]
    #  and add it to our newly defined dictionary of dataframes
    final_Timepoint_df_dict[drug] = final_Timepoint_df.loc[final_Timepoint_df['Drug Regimen'] == drug]
    
    # Calculate the IQR and quantitatively determine if there are any potential outliers. 
    quartiles = final_Timepoint_df_dict[drug]['Tumor Volume (mm3)'].quantile([0.25,0.5,0.75])
    lowerq = quartiles[0.25]
    median_final_tumor_vol = quartiles[0.5]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    # print out all the requested data
    print(f'{drug}:')
    print(f"The lower quartile of final tumor volumes is: {round(lowerq,1)} mm3")
    print(f"The the median of final tumor volumes is: {round(median_final_tumor_vol,1)} mm3")
    print(f"The upper quartile of final tumor volumes is: {round(upperq,1)} mm3")
    print(f"The interquartile range of final tumor volumes is: {round(iqr,1)} mm3")
    print(f"Tumors above {round(upper_bound,1)} cubic mm could be outliers.")
    
    ### this if-statement is just in case any of the outlier thresholds have a negative volume
    if lower_bound > 0:
        print(f"Tumors below {round(lower_bound,1)} cubic mm could be outliers.")
    else:
        pass
    
    print('_'*60)
    print()
# Out:
# Capomulin:
# The lower quartile of final tumor volumes is: 32.4 mm3
# The the median of final tumor volumes is: 38.1 mm3
# The upper quartile of final tumor volumes is: 40.2 mm3
# The interquartile range of final tumor volumes is: 7.8 mm3
# Tumors above 51.8 cubic mm could be outliers.
# Tumors below 20.7 cubic mm could be outliers.
# ____________________________________________________________
#
# Ramicane:
# The lower quartile of final tumor volumes is: 31.6 mm3
# The the median of final tumor volumes is: 36.6 mm3
# The upper quartile of final tumor volumes is: 40.7 mm3
# The interquartile range of final tumor volumes is: 9.1 mm3
# Tumors above 54.3 cubic mm could be outliers.
# Tumors below 17.9 cubic mm could be outliers.
# ____________________________________________________________
#
# Infubinol:
# The lower quartile of final tumor volumes is: 54.0 mm3
# The the median of final tumor volumes is: 60.2 mm3
# The upper quartile of final tumor volumes is: 65.5 mm3
# The interquartile range of final tumor volumes is: 11.5 mm3
# Tumors above 82.7 cubic mm could be outliers.
# Tumors below 36.8 cubic mm could be outliers.
# ____________________________________________________________
#
# Ceftamin:
# The lower quartile of final tumor volumes is: 48.7 mm3
# The the median of final tumor volumes is: 59.9 mm3
# The upper quartile of final tumor volumes is: 64.3 mm3
# The interquartile range of final tumor volumes is: 15.6 mm3
# Tumors above 87.7 cubic mm could be outliers.
# Tumors below 25.4 cubic mm could be outliers.
# ____________________________________________________________

# %%
# Generate a box plot of the final tumor volume of each mouse across 
#  the four regimens of interest

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

bp1 = ax1.boxplot([final_Timepoint_df_dict['Ramicane']['Tumor Volume (mm3)'],
             final_Timepoint_df_dict['Capomulin']['Tumor Volume (mm3)']],
            patch_artist=True,boxprops=dict(color='g', facecolor='w'),
            medianprops=dict(color='g'),capprops=dict(color='g'),
            whiskerprops=dict(color='g'),
            positions=[1,3])


bp2 = ax2.boxplot([final_Timepoint_df_dict['Infubinol']['Tumor Volume (mm3)'],
             final_Timepoint_df_dict['Ceftamin']['Tumor Volume (mm3)']],
            patch_artist=True,boxprops=dict(color='r', facecolor='w'),
            medianprops=dict(color='r'),capprops=dict(color='r'),
            whiskerprops=dict(color='r'),flierprops=dict(markeredgecolor='r'),
            positions=[5,7])

ax1.set_title('Final Tumor Volums')
ax1.set_xticklabels(['Ramicane','Capomulin', 'Infubinol', 'Ceftamin'])
ax1.set_xlim(0,9)
ax1.set_ylabel('Volums (cubic mm)',color='g')
ax2.set_ylabel('Volums (cubic mm)', color='r')
ax1.legend([bp1['boxes'][0], bp2['boxes'][0]], ['Successful Drug', 'Unsuccessful Drug'], loc='lower right')
plt.show()

# %% [markdown]
# ## Line and scatter plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# choose the mouse
s185_df = combined_df.loc[(combined_df['Mouse ID'] == 's185')]

# set Timepoint to be our index (x_axis)
s185_df = s185_df.set_index('Timepoint')

# shrink our dataframe to only tumor volume (y_axis)
s185_df = s185_df['Tumor Volume (mm3)']

s185_df.plot(kind='line', marker='o', label='s185')
plt.ylabel('Tumor Volume (cubic mm)')
plt.legend(loc='best')
plt.show()

# %%
# I'm going do the average Capomulin mouse's tumor volume as it's more representative

# choose a drug
Capomulin_df = combined_df.loc[(combined_df['Drug Regimen'] == 'Capomulin')]

# set Timepoint to be our index (x_axis)
Capomulin_groupedby_Timepoint = Capomulin_df.groupby('Timepoint')

# plot only the tumor volume (y_axis)
Capomulin_groupedby_Timepoint.mean()['Tumor Volume (mm3)'].plot(
    kind='line', marker='^', label='Capomulin')
plt.ylabel('Average Tumor Volume (cubic mm)')
plt.legend(loc='best')
plt.show()

# %%
# You know, while we're at it, let's just plot them all!

# We want a specific ratio to see the spread of data
plt.figure(figsize=(6,5))

# This get's a little ugly but it's mainly just copy.pasting what is above
#  and putting it all into one big line of list comprehension
[combined_df.loc[(combined_df['Drug Regimen'] == str(drug))].groupby('Timepoint').mean()['Tumor Volume (mm3)'].plot(
    kind='line', label=str(drug)) for drug in list(combined_df['Drug Regimen'].unique())]

# Adding an hline so we can see where every tumor starts
plt.hlines(45, 0, 45, alpha=0.1)

plt.ylabel('Average Tumor Volume (cubic mm)')
plt.legend(loc='upper left',fontsize="small")
plt.title('Tumor Volume Mean Change over Time')
plt.show()
# We can see that all but two drugs are no better or worse than the Placebo

# %%
# Generate a scatter plot of mouse weight versus average tumor volume 
#  for the Capomulin regimen

# We start by groping just the Capomulin dataframe we used above by ID 
Capomulin_groupedby_ID = Capomulin_df.groupby('Mouse ID')
# Then make a new dataframe of the averages (because we'll want the ave volume)
Capomulin_groupedby_ID_mean_df = pd.DataFrame(Capomulin_groupedby_ID.mean())

# Calculate the desired points
weights = Capomulin_groupedby_ID_mean_df['Weight (g)']
ave_volumes =  Capomulin_groupedby_ID_mean_df['Tumor Volume (mm3)']

plt.scatter(weights, ave_volumes)
plt.title('Average Tumor Volumes v Mouse Weight')
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (cubic mm)')
plt.show()

# %%
# Calculate the correlation coefficient and linear regression model 
#  for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(weights, ave_volumes)
print(f"The correlation between weight and tumor size is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(weights, ave_volumes)
regress_values = weights * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weights, ave_volumes)
plt.plot(weights,regress_values,"r-")
plt.annotate(line_eq,(17.5,37.5),fontsize=15,color="red")
plt.title('Average Tumor Volumes v Mouse Weight')
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (cubic mm)')
plt.show()
# Out:
# The correlation between weight and tumor size is 0.84
